# %%
#Question 2

# %%
import numpy as np
import pandas as pd
from pandas import DataFrame

import matplotlib
import matplotlib.pyplot as plt

# %%
plane_data = pd.read_csv('plane-data.csv')
plane_data
# Out:
#      tailnum                 type                   manufacturer  issue_date  \
# 0     N050AA                  NaN                            NaN         NaN
# 1     N051AA                  NaN                            NaN         NaN
# 2     N052AA                  NaN                            NaN         NaN
# 3     N054AA                  NaN                            NaN         NaN
# 4     N055AA                  NaN                            NaN         NaN
# ...      ...                  ...                            ...         ...
# 5024  N997DL          Corporation  MCDONNELL DOUGLAS AIRCRAFT CO  03/11/1992
# 5025  N998AT          Corporation                         BOEING  01/23/2003
# 5026  N998DL          Corporation  MCDONNELL DOUGLAS CORPORATION  04/02/1992
# 5027  N999CA  Foreign Corporation                       CANADAIR  07/09/2008
# 5028  N999DN          Corporation  MCDONNELL DOUGLAS CORPORATION  04/02/1992
#
# ...

# %%
plane_data.dropna()
# Out:
#      tailnum                 type                   manufacturer  issue_date  \
# 34    N10156          Corporation                        EMBRAER  02/13/2004
# 35    N102UW          Corporation               AIRBUS INDUSTRIE  05/26/1999
# 36    N10323          Corporation                         BOEING  07/01/1997
# 37    N103US          Corporation               AIRBUS INDUSTRIE  06/18/1999
# 38    N104UA          Corporation                         BOEING  01/26/1998
# ...      ...                  ...                            ...         ...
# 5024  N997DL          Corporation  MCDONNELL DOUGLAS AIRCRAFT CO  03/11/1992
# 5025  N998AT          Corporation                         BOEING  01/23/2003
# 5026  N998DL          Corporation  MCDONNELL DOUGLAS CORPORATION  04/02/1992
# 5027  N999CA  Foreign Corporation                       CANADAIR  07/09/2008
# 5028  N999DN          Corporation  MCDONNELL DOUGLAS CORPORATION  04/02/1992
#
# ...

# %%
##Subsetting top 5 oldest plane tail numbers for 2006

# %%
##Using df4 and df from Question 1

# %%
df4 = pd.read_csv('2006.csv')
df4
# Out:
#          Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0        2006      1          11          3    743.0         745   1024.0
# 1        2006      1          11          3   1053.0        1053   1313.0
# 2        2006      1          11          3   1915.0        1915   2110.0
# 3        2006      1          11          3   1753.0        1755   1925.0
# 4        2006      1          11          3    824.0         832   1015.0
# ...       ...    ...         ...        ...      ...         ...      ...
# 7141917  2006     12          29          5   1246.0        1249   1452.0
# 7141918  2006     12          29          5   1225.0        1155   2033.0
# 7141919  2006     12          29          5   2118.0        2115   2254.0
# 7141920  2006     12          29          5   2122.0        2127   2209.0
# 7141921  2006     12          29          5   2042.0        2045   2213.0
#
#          CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# ...

# %%
oldN567AA06 = df4[df4['TailNum']=="N567AA"]
oldN567AA06
# Out:
#          Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 440435   2006      1          16          1   1633.0        1630   1755.0
# 442182   2006      1          17          2   1656.0        1657   1900.0
# 442785   2006      1          12          4   1638.0        1638   1940.0
# 443134   2006      1          12          4    624.0         630   1203.0
# 443165   2006      1          12          4   1236.0        1237   1554.0
# ...       ...    ...         ...        ...      ...         ...      ...
# 7041372  2006     12           9          6   1052.0        1055   1301.0
# 7041711  2006     12           9          6   1953.0        1955   2200.0
# 7041815  2006     12           9          6   1658.0        1700   1913.0
# 7042621  2006     12          28          4    820.0         825    940.0
# 7042907  2006     12          11          1   1502.0        1505   1635.0
#
#          CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# ...

# %%
oldN402AA06 = df4[df4['TailNum']=="N402AA"]
oldN402AA06
# Out:
#          Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
#
0
#
#          CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# ...

# %%
newN358AA06 = df4[df4['TailNum']=="N358AA"]
newN358AA06
# Out:
#          Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 436466   2006      1          11          3    746.0         750   1615.0
# 436804   2006      1          13          5   1619.0        1610   1748.0
# 436948   2006      1           2          1    856.0         855   1504.0
# 437632   2006      1           4          3   1759.0        1800   2124.0
# 438968   2006      1           2          1   1634.0        1555   2342.0
# ...       ...    ...         ...        ...      ...         ...      ...
# 7029664  2006     12          25          1     29.0        2355    618.0
# 7030152  2006     12          26          2   1035.0        1035   1430.0
# 7033488  2006     12          24          7   1821.0        1735     22.0
# 7042423  2006     12          21          4    721.0         725    831.0
# 7043245  2006     12          21          4    949.0         950   1439.0
#
#          CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# ...

# %%
newN738AL06 = df4[df4['TailNum']=="N738AL"]
newN738AL06
# Out:
#          Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 2213216  2006      4          13          4    825.0         830   1032.0
# 2213224  2006      4          21          5    822.0         830   1048.0
# 2213231  2006      4          28          5    826.0         830   1048.0
# 2213244  2006      4          14          5   1324.0        1324   2140.0
# 2213252  2006      4          22          6   1331.0        1324   2141.0
# ...       ...    ...         ...        ...      ...         ...      ...
# 7048786  2006     12           7          4   2112.0        2125   2233.0
# 7048791  2006     12          12          2   2117.0        2125   2239.0
# 7048794  2006     12          15          5   2118.0        2125   2236.0
# 7048798  2006     12          19          2   2125.0        2125   2244.0
# 7048803  2006     12          24          7   2130.0        2125   2249.0
#
#          CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# ...

# %%
newN843AL06 = df4[df4['TailNum']=="N843AL"]
newN843AL06
# Out:
# Empty DataFrame
# Columns: [Year, Month, DayofMonth, DayOfWeek, DepTime, CRSDepTime, ArrTime, CRSArrTime, UniqueCarrier, FlightNum, TailNum, ActualElapsedTime, CRSElapsedTime, AirTime, ArrDelay, DepDelay, Origin, Dest, Distance, TaxiIn, TaxiOut, Cancelled, CancellationCode, Diverted, CarrierDelay, WeatherDelay, NASDelay, SecurityDelay, LateAircraftDelay]
# Index: []
#
# [0 rows x 29 columns]

# %%
newN999CA06 = df4[df4['TailNum']=="N999CA"]
newN999CA06
# Out:
#          Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 147590   2006      1          19          4   1815.0        1625   1831.0
# 148093   2006      1          20          5   1204.0        1205   1312.0
# 148184   2006      1          20          5   1350.0        1345   1517.0
# 148725   2006      1          21          6    826.0         820   1018.0
# 149010   2006      1          21          6   1440.0        1440   1733.0
# ...       ...    ...         ...        ...      ...         ...      ...
# 6990107  2006     12          14          4   2005.0        1955   2112.0
# 6990336  2006     12          15          5    900.0         900   1008.0
# 6990444  2006     12          15          5   1100.0        1100   1220.0
# 6990542  2006     12          15          5   1315.0        1315   1534.0
# 6990703  2006     12          15          5   1625.0        1625   1802.0
#
#          CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# ...

# %%
##finding mean of departure delay for each plane in 2006

# %%
oldN567AA06["DepDelay"].mean()
# Out:
# 10.062259800153727

# %%
oldN402AA06["DepDelay"].mean()
# Out:
# 9.682617874736101

# %%
oldN444AA06["DepDelay"].mean()
# Out:
# 9.570175438596491

# %%
oldN227AA06["DepDelay"].mean()
# Out:
# 9.419239052404881

# %%
oldN300SW06["DepDelay"].mean()
# Out:
# 10.763615733736762

# %%
newN739AL06["DepDelay"].mean()
# Out:
# 6.574792243767313

# %%
newN358AA06["DepDelay"].mean()
# Out:
# 8.599033816425122

# %%
newN738AL06["DepDelay"].mean()
# Out:
# 7.730978260869565

# %%
newN843AL06["DepDelay"].mean()
# Out:
# nan

# %%
newN999CA06["DepDelay"].mean()
# Out:
# 12.332674571805006

# %%
##finding mean of arrival delay for each plane in 2006

# %%
oldN567AA06["ArrDelay"].mean()
# Out:
# 9.487692307692308

# %%
oldN402AA06["ArrDelay"].mean()
# Out:
# 8.190106007067138

# %%
oldN444AA06["ArrDelay"].mean()
# Out:
# 8.74670571010249

# %%
oldN227AA06["ArrDelay"].mean()
# Out:
# 8.478073328540619

# %%
oldN300SW06["ArrDelay"].mean()
# Out:
# 6.421969696969697

# %%
newN739AL06["ArrDelay"].mean()
# Out:
# 3.592797783933518

# %%
newN358AA06["ArrDelay"].mean()
# Out:
# 8.951690821256038

# %%
newN738AL06["ArrDelay"].mean()
# Out:
# 4.407356948228883

# %%
newN843AL06["ArrDelay"].mean()
# Out:
# nan

# %%
newN999CA06["ArrDelay"].mean()
# Out:
# 13.44825313117996

# %%
##using dataframe from Question 1

# %%
df = pd.read_csv('2007.csv')
df
# Out:
#          Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0        2007      1           1          1   1232.0        1225   1341.0
# 1        2007      1           1          1   1918.0        1905   2043.0
# 2        2007      1           1          1   2206.0        2130   2334.0
# 3        2007      1           1          1   1230.0        1200   1356.0
# 4        2007      1           1          1    831.0         830    957.0
# ...       ...    ...         ...        ...      ...         ...      ...
# 7453210  2007     12          15          6   1558.0        1605   1749.0
# 7453211  2007     12          15          6   1902.0        1851   2110.0
# 7453212  2007     12          15          6   1024.0        1025   1750.0
# 7453213  2007     12          15          6   1353.0        1315   1658.0
# 7453214  2007     12          15          6   1824.0        1800   2001.0
#
#          CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# ...

# %%
##subsetting top 5 oldest planes for 2007

# %%
oldN567AA07 = df[df['TailNum']=="N567AA"] 
oldN567AA07
# Out:
#          Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 494013   2007      1          24          3   1557.0        1600   1802.0
# 494044   2007      1          24          3   1401.0        1400   1511.0
# 495185   2007      1          21          7   1127.0        1015   1400.0
# 495796   2007      1          24          3   1210.0        1210   1323.0
# 495870   2007      1           1          1    726.0         725   1059.0
# ...       ...    ...         ...        ...      ...         ...      ...
# 7371689  2007     12           6          4   1949.0        1930   2115.0
# 7371912  2007     12          25          2   1924.0        1905   2126.0
# 7372682  2007     12          16          7   1239.0        1235   1408.0
# 7372741  2007     12           1          6   1333.0        1245   1742.0
# 7372813  2007     12          27          4    654.0         655    951.0
#
#          CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# ...

# %%
oldN402AA07 = df[df['TailNum']=="N402AA"]
oldN402AA07
# Out:
#          Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 490929   2007      1           4          4   1004.0        1005   1140.0
# 490938   2007      1          13          6   1005.0        1005   1140.0
# 490964   2007      1           8          1   1249.0        1255   1426.0
# 490995   2007      1           8          1    928.0         930   1156.0
# 491718   2007      1          11          4   2117.0        2115   2257.0
# ...       ...    ...         ...        ...      ...         ...      ...
# 7371587  2007     12          26          3   1719.0        1650   1844.0
# 7371599  2007     12           7          5   1545.0        1535   1754.0
# 7371652  2007     12          30          7   2035.0        2015   2306.0
# 7373688  2007     12          12          3   1150.0        1155   1411.0
# 7373696  2007     12          20          4   1151.0        1140   1417.0
#
#          CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# ...

# %%
oldN444AA07 = df[df['TailNum']=="N444AA"]
oldN444AA07
# Out:
#          Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 490326   2007      1           4          4    800.0         805   1134.0
# 490357   2007      1           4          4    605.0         610    704.0
# 490483   2007      1          18          4    708.0         710    858.0
# 490514   2007      1          18          4    931.0         930   1127.0
# 491067   2007      1          18          4   1441.0        1355   1553.0
# ...       ...    ...         ...        ...      ...         ...      ...
# 7371936  2007     12          21          5   2203.0        1955     14.0
# 7372754  2007     12          14          5   1218.0        1220   1520.0
# 7372759  2007     12          19          3   1219.0        1220   1501.0
# 7372786  2007     12          29          6   1358.0        1400   1649.0
# 7373135  2007     12          17          1    710.0         715    958.0
#
#          CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# ...

# %%
0
#
#          CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# ...

# %%
newN843AL07 = df[df['TailNum']=="N843AL"]
newN843AL07
# Out:
#          Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 7374643  2007     12          11          2   1721.0        1710   1800.0
# 7374658  2007     12          26          3   1708.0        1710   1742.0
# 7374674  2007     12          11          2   1628.0        1600   1704.0
# 7374689  2007     12          26          3   1600.0        1600   1640.0
# 7374716  2007     12          22          6   1856.0        1850   1933.0
# ...       ...    ...         ...        ...      ...         ...      ...
# 7377138  2007     12          25          2   1611.0        1610   1702.0
# 7377169  2007     12          25          2   1507.0        1510   1538.0
# 7377504  2007     12          19          3   1748.0        1755   1818.0
# 7377838  2007     12          22          6   1632.0        1630   1703.0
# 7377869  2007     12          22          6   1530.0        1520   1612.0
#
#          CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# ...

# %%
newN999CA07 = df[df['TailNum']=="N999CA"]
newN999CA07
# Out:
#          Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 155022   2007      1           1          1   1833.0        1833   2125.0
# 155243   2007      1           2          2    651.0         700    716.0
# 155276   2007      1           2          2    738.0         740    950.0
# 155381   2007      1           2          2   1015.0        1015   1238.0
# 155596   2007      1           2          2   1459.0        1459   1712.0
# ...       ...    ...         ...        ...      ...         ...      ...
# 7010504  2007     12          27          4   2040.0        1925   2235.0
# 7010531  2007     12          27          4    935.0         935   1002.0
# 7010695  2007     12          27          4   1722.0        1719   1854.0
# 7010797  2007     12          27          4   1450.0        1450   1635.0
# 7010914  2007     12          27          4   1030.0        1035   1405.0
#
#          CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# ...

# %%
##finding mean of departure delay for each plane in 2007

# %%
oldN567AA07["DepDelay"].mean()
# Out:
# 11.445004198152812

# %%
oldN402AA07["DepDelay"].mean()
# Out:
# 11.822408536585366

# %%
oldN444AA07["DepDelay"].mean()
# Out:
# 15.015897047691142

# %%
oldN227AA07["DepDelay"].mean()
# Out:
# 16.637537993920972

# %%
oldN300SW07["DepDelay"].mean()
# Out:
# 11.172981056829512

# %%
newN739AL07["DepDelay"].mean()
# Out:
# 5.565302144249513

# %%
newN358AA07["DepDelay"].mean()
# Out:
# 15.921259842519685

# %%
newN738AL07["DepDelay"].mean()
# Out:
# 3.65024154589372

# %%
newN843AL07["DepDelay"].mean()
# Out:
# -0.819672131147541

# %%
newN999CA07["DepDelay"].mean()
# Out:
# 10.860131500298865

# %%
##finding mean of arrival delay for each plane in 2007

# %%
oldN567AA07["ArrDelay"].mean()
# Out:
# 10.576599326599327

# %%
oldN402AA07["ArrDelay"].mean()
# Out:
# 10.919663351185921

# %%
oldN444AA07["ArrDelay"].mean()
# Out:
# 15.031987814166031

# %%
oldN227AA07["ArrDelay"].mean()
# Out:
# 17.3768115942029

# %%
oldN300SW07["ArrDelay"].mean()
# Out:
# 7.472263868065967

# %%
newN739AL07["ArrDelay"].mean()
# Out:
# -1.9522417153996101

# %%
newN358AA07["ArrDelay"].mean()
# Out:
# 12.964426877470355

# %%
newN738AL07["ArrDelay"].mean()
# Out:
# -4.488888888888889

# %%
newN843AL07["ArrDelay"].mean()
# Out:
# -1.5163934426229508

# %%
newN999CA07["ArrDelay"].mean()
# Out:
# 10.9061004784689

# %%
#Comparing delay between new and old planes

# %%
##departure delay in 2006

# %%
dfdepdelay06 = DataFrame({'Tail Number_old': ['N567AA', 'N402AA', 'N444AA', 'N227AA', 'N300SW'],
                         'DepDelay_old':[10.06, 9.68, 9.57, 9.42, 10.76],
                         'DepDelay_new':[6.57, 8.60, 7.73, 'NA', 12.33],
                         'Tail Number_new': ['N739AL', 'N358AA', 'N738AL', 'N843AL', 'N999CA']})
dfdepdelay06
# Out:
#   Tail Number_old  DepDelay_old DepDelay_new Tail Number_new
# 0          N567AA         10.06         6.57          N739AL
# 1          N402AA          9.68          8.6          N358AA
# 2          N444AA          9.57         7.73          N738AL
# 3          N227AA          9.42           NA          N843AL
# 4          N300SW         10.76        12.33          N999CA

# %%
#Arrival delay in 2006

# %%
dfarrdelay06 = DataFrame({'Tail Number_old': ['N567AA', 'N402AA', 'N444AA', 'N227AA', 'N300SW'],
                         'ArrDelay_old':[9.49, 8.19, 8.75, 8.48, 6.42],
                         'ArrDelay_new':[3.59, 8.95, 4.41, 'NA', 13.45],
                         'Tail Number_new': ['N739AL', 'N358AA', 'N738AL', 'N843AL', 'N999CA']})
dfarrdelay06
# Out:
#   Tail Number_old  ArrDelay_old ArrDelay_new Tail Number_new
# 0          N567AA          9.49         3.59          N739AL
# 1          N402AA          8.19         8.95          N358AA
# 2          N444AA          8.75         4.41          N738AL
# 3          N227AA          8.48           NA          N843AL
# 4          N300SW          6.42        13.45          N999CA

# %%
#Departure delay for 2007

# %%
dfdepdelay07 = DataFrame({'Tail Number_old': ['N567AA', 'N402AA', 'N444AA', 'N227AA', 'N300SW'],
                         'DepDelay_old':[11.45, 11.82, 15.02, 16.64, 11.17],
                         'DepDelay_new':[5.57, 15.92, 3.65, -0.82, 10.86],
                         'Tail Number_new': ['N739AL', 'N358AA', 'N738AL', 'N843AL', 'N999CA']})
dfdepdelay07
# Out:
#   Tail Number_old  DepDelay_old DepDelay_new Tail Number_new
# 0          N567AA         11.45         6.57          N739AL
# 1          N402AA         11.82          8.6          N358AA
# 2          N444AA         15.02         7.73          N738AL
# 3          N227AA         16.64           NA          N843AL
# 4          N300SW         11.17        12.33          N999CA

# %%
dfarrdelay07 = DataFrame({'Tail Number_old': ['N567AA', 'N402AA', 'N444AA', 'N227AA', 'N300SW'],
                         'ArrDelay_old':[10.58, 10.92, 15.03, 17.38, 7.47],
                         'ArrDelay_new':[-1.95, 12.96, -4.48, -1.52, 10.91],
                         'Tail Number_new': ['N739AL', 'N358AA', 'N738AL', 'N843AL', 'N999CA']})
dfarrdelay07
# Out:
#   Tail Number_old  ArrDelay_old ArrDelay_new Tail Number_new
# 0          N567AA         10.58         3.59          N739AL
# 1          N402AA         10.92         8.95          N358AA
# 2          N444AA         15.03         4.41          N738AL
# 3          N227AA         17.38           NA          N843AL
# 4          N300SW          7.47        13.45          N999CA
