# %%
#Question 1

# %%
import pandas as pd

import matplotlib
import matplotlib.pyplot as plt

# %%
# !pip install numpy

# %%
import numpy as np

# %%
df = pd.read_csv('2007.csv')

# %%
df
# Out:
#          Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0        2007      1           1          1   1232.0        1225   1341.0
# 1        2007      1           1          1   1918.0        1905   2043.0
# 2        2007      1           1          1   2206.0        2130   2334.0
# 3        2007      1           1          1   1230.0        1200   1356.0
# 4        2007      1           1          1    831.0         830    957.0
# ...       ...    ...         ...        ...      ...         ...      ...
# 7453210  2007     12          15          6   1558.0        1605   1749.0
# 7453211  2007     12          15          6   1902.0        1851   2110.0
# 7453212  2007     12          15          6   1024.0        1025   1750.0
# 7453213  2007     12          15          6   1353.0        1315   1658.0
# 7453214  2007     12          15          6   1824.0        1800   2001.0
#
#          CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# ...

# %%
df1 = df.drop_duplicates()

# %%
df1
# Out:
#          Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0        2007      1           1          1   1232.0        1225   1341.0
# 1        2007      1           1          1   1918.0        1905   2043.0
# 2        2007      1           1          1   2206.0        2130   2334.0
# 3        2007      1           1          1   1230.0        1200   1356.0
# 4        2007      1           1          1    831.0         830    957.0
# ...       ...    ...         ...        ...      ...         ...      ...
# 7453210  2007     12          15          6   1558.0        1605   1749.0
# 7453211  2007     12          15          6   1902.0        1851   2110.0
# 7453212  2007     12          15          6   1024.0        1025   1750.0
# 7453213  2007     12          15          6   1353.0        1315   1658.0
# 7453214  2007     12          15          6   1824.0        1800   2001.0
#
#          CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# ...

# %%
import numpy as np
import pandas as pd
import os

import matplotlib
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df4 = pd.read_csv('2006.csv')

# %%
df5 = df4.drop_duplicates()

# %%
df4
# Out:
#          Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0        2006      1          11          3    743.0         745   1024.0
# 1        2006      1          11          3   1053.0        1053   1313.0
# 2        2006      1          11          3   1915.0        1915   2110.0
# 3        2006      1          11          3   1753.0        1755   1925.0
# 4        2006      1          11          3    824.0         832   1015.0
# ...       ...    ...         ...        ...      ...         ...      ...
# 7141917  2006     12          29          5   1246.0        1249   1452.0
# 7141918  2006     12          29          5   1225.0        1155   2033.0
# 7141919  2006     12          29          5   2118.0        2115   2254.0
# 7141920  2006     12          29          5   2122.0        2127   2209.0
# 7141921  2006     12          29          5   2042.0        2045   2213.0
#
#          CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# ...

# %%
df5
# Out:
#          Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0        2006      1          11          3    743.0         745   1024.0
# 1        2006      1          11          3   1053.0        1053   1313.0
# 2        2006      1          11          3   1915.0        1915   2110.0
# 3        2006      1          11          3   1753.0        1755   1925.0
# 4        2006      1          11          3    824.0         832   1015.0
# ...       ...    ...         ...        ...      ...         ...      ...
# 7141917  2006     12          29          5   1246.0        1249   1452.0
# 7141918  2006     12          29          5   1225.0        1155   2033.0
# 7141919  2006     12          29          5   2118.0        2115   2254.0
# 7141920  2006     12          29          5   2122.0        2127   2209.0
# 7141921  2006     12          29          5   2042.0        2045   2213.0
#
#          CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# ...

# %%
df5.head()
# Out:
#    Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0  2006      1          11          3    743.0         745   1024.0
# 1  2006      1          11          3   1053.0        1053   1313.0
# 2  2006      1          11          3   1915.0        1915   2110.0
# 3  2006      1          11          3   1753.0        1755   1925.0
# 4  2006      1          11          3    824.0         832   1015.0
#
#    CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# 0        1018            US        343  ...     45       13          0
# 1        1318            US        613  ...     27       19          0
# 2        2133            US        617  ...      4       11          0
# 3        1933            US        300  ...     16       10          0
# 4        1015            US        765  ...     27       12          0
#
#    CancellationCode  Diverted  CarrierDelay WeatherDelay NASDelay  \
# ...

# %%
len(df5)
# Out:
# 7141915

# %%
#subsetting 2006 by months
import pandas as pd
df11 = pd.read_csv('2006.csv')
monthjanDF = df11[df11['Month']==1]

# %%
monthjanDF
# Out:
#         Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0       2006      1          11          3    743.0         745   1024.0
# 1       2006      1          11          3   1053.0        1053   1313.0
# 2       2006      1          11          3   1915.0        1915   2110.0
# 3       2006      1          11          3   1753.0        1755   1925.0
# 4       2006      1          11          3    824.0         832   1015.0
# ...      ...    ...         ...        ...      ...         ...      ...
# 581282  2006      1          30          1   1303.0        1300   1542.0
# 581283  2006      1          30          1   2245.0        2245     28.0
# 581284  2006      1          30          1   1724.0        1725   1926.0
# 581285  2006      1          30          1   1244.0        1246   1749.0
# 581286  2006      1          30          1      NaN        1830      NaN
#
#         CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# ...

# %%
import pandas as pd
df11 = pd.read_csv('2006.csv')
monthfebDF = df11[df11['Month']==2]

monthfebDF
# Out:
#          Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
#
0
# ...       ...    ...         ...        ...      ...         ...      ...
# 6537159  2006     11          29          3   1454.0        1445   1817.0
# 6537160  2006     11          29          3   1907.0        1920   2307.0
# 6537161  2006     11          29          3   1109.0        1100   1403.0
# 6537162  2006     11          29          3   1402.0        1403   1428.0
# 6537163  2006     11          29          3   1756.0        1759   2225.0
#
#          CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# ...

# %%
df11 = pd.read_csv('2006.csv')
monthdecDF = df11[df11['Month']==12]

monthdecDF
# Out:
#          Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 6537164  2006     12           3          7    814.0         815    900.0
# 6537165  2006     12           3          7   1446.0        1440   1542.0
# 6537166  2006     12           3          7   1939.0        1935   2038.0
# 6537167  2006     12           3          7   1122.0        1120   1314.0
# 6537168  2006     12           3          7   1338.0        1340   1534.0
# ...       ...    ...         ...        ...      ...         ...      ...
# 7141917  2006     12          29          5   1246.0        1249   1452.0
# 7141918  2006     12          29          5   1225.0        1155   2033.0
# 7141919  2006     12          29          5   2118.0        2115   2254.0
# 7141920  2006     12          29          5   2122.0        2127   2209.0
# 7141921  2006     12          29          5   2042.0        2045   2213.0
#
#          CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# ...

# %%
monthjanDF["DepDelay"].mean()
# Out:
# 8.07821697287839

# %%
monthfebDF["DepDelay"].mean()
# Out:
# 9.142587613519657

# %%
monthmarDF["DepDelay"].mean()
# Out:
# 9.755770701319042

# %%
monthaprDF["DepDelay"].mean()
# Out:
# 8.194027787617042

# %%
monthmayDF["DepDelay"].mean()
# Out:
# 8.540831601948103

# %%
monthjunDF["DepDelay"].mean()
# Out:
# 12.933676964845205

# %%
monthjulDF["DepDelay"].mean()
# Out:
# 12.703435985382688

# %%
monthaugDF["DepDelay"].mean()
# Out:
# 9.9368251665323

# %%
monthsepDF["DepDelay"].mean()
# Out:
# 8.760105880654693

# %%
monthoctDF["DepDelay"].mean()
# Out:
# 10.645491813519145

# %%
monthnovDF["DepDelay"].mean()
# Out:
# 8.958552924793501

# %%
monthdecDF["DepDelay"].mean()
# Out:
# 13.155174000790913

# %%
monthjanDF["ArrDelay"].mean()
# Out:
# 5.628670654061354

# %%
monthfebDF["ArrDelay"].mean()
# Out:
# 7.359394190631357

# %%
monthmarDF["ArrDelay"].mean()
# Out:
# 7.926261109192763

# %%
monthaprDF["ArrDelay"].mean()
# Out:
# 6.42371018386133

# %%
monthmayDF["ArrDelay"].mean()
# Out:
# 6.887169414051858

# %%
monthjunDF["ArrDelay"].mean()
# Out:
# 12.0455579467206

# %%
monthjulDF["ArrDelay"].mean()
# Out:
# 11.311533589317666

# %%
monthaugDF["ArrDelay"].mean()
# Out:
# 8.687386516224231

# %%
monthsepDF["ArrDelay"].mean()
# Out:
# 8.394922875816993

# %%
monthoctDF["ArrDelay"].mean()
# Out:
# 10.687462234136667

# %%
monthnovDF["ArrDelay"].mean()
# Out:
# 7.258614938235141

# %%
monthdecDF["ArrDelay"].mean()
# Out:
# 11.179542468360811

# %%
#subsetting 2007 by months
import pandas as pd
df12 = pd.read_csv('2007.csv')
monthjanDF07 = df12[df12['Month']==1]
monthfebDF07 = df12[df12['Month']==2]
monthmarDF07 = df12[df12['Month']==3]
monthaprDF07 = df12[df12['Month']==4]
monthmayDF07 = df12[df12['Month']==5]
monthjunDF07 = df12[df12['Month']==6]
monthjulDF07 = df12[df12['Month']==7]
monthaugDF07 = df12[df12['Month']==8]
monthsepDF07 = df12[df12['Month']==9]
monthoctDF07 = df12[df12['Month']==10]
monthnovDF07 = df12[df12['Month']==11]
monthdecDF07 = df12[df12['Month']==12]

# %%
monthjanDF07
# Out:
#         Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0       

# Out:
#          Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 6233927  2007     11           2          5    735.0         740    925.0
# 6233928  2007     11           2          5   2048.0        2050   2217.0
# 6233929  2007     11           2          5   1128.0        1130   1311.0
# 6233930  2007     11           2          5   2001.0        2005   2100.0
# 6233931  2007     11           2          5   2157.0        2130   2301.0
# ...       ...    ...         ...        ...      ...         ...      ...
# 6839071  2007     11          16          5    703.0         650   1429.0
# 6839072  2007     11          16          5   2250.0        2255    613.0
# 6839073  2007     11          16          5   1408.0        1406   1528.0
# 6839074  2007     11          16          5   2153.0        2150     36.0
# 6839075  2007     11          16          5   1736.0        1740   2001.0
#
#          CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# ...

# %%
monthdecDF07
# Out:
#          Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 6839076  2007     12           2          7   1028.0        1010   1030.0
# 6839077  2007     12           2          7    728.0         730    722.0
# 6839078  2007     12           2          7   1546.0        1545   1545.0
# 6839079  2007     12           2          7   2039.0        2030   2037.0
# 6839080  2007     12           2          7   1541.0        1540   1557.0
# ...       ...    ...         ...        ...      ...         ...      ...
# 7453210  2007     12          15          6   1558.0        1605   1749.0
# 7453211  2007     12          15          6   1902.0        1851   2110.0
# 7453212  2007     12          15          6   1024.0        1025   1750.0
# 7453213  2007     12          15          6   1353.0        1315   1658.0
# 7453214  2007     12          15          6   1824.0        1800   2001.0
#
#          CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# ...

# %%
monthjanDF07["DepDelay"].mean()
# Out:
# 10.286743415948312

# %%
monthfebDF07["DepDelay"].mean()
# Out:
# 14.02253123732965

# %%
monthmarDF07["DepDelay"].mean()
# Out:
# 11.836802542694253

# %%
monthaprDF07["DepDelay"].mean()
# Out:
# 10.07771370814071

# %%
monthmayDF07["DepDelay"].mean()
# Out:
# 8.329205401044868

# %%
monthjunDF07["DepDelay"].mean()
# Out:
# 16.214701071994014

# %%
monthjulDF07["DepDelay"].mean()
# Out:
# 14.802613636005757

# %%
monthaugDF07["DepDelay"].mean()
# Out:
# 13.515875591278409

# %%
monthsepDF07["DepDelay"].mean()
# Out:
# 6.157685958765665

# %%
monthoctDF07["DepDelay"].mean()
# Out:
# 7.973724233737243

# %%
monthnovDF07["DepDelay"].mean()
# Out:
# 7.446888306310218

# %%
monthdecDF07["DepDelay"].mean()
# Out:
# 16.201398473962534

# %%
monthjanDF07["ArrDelay"].mean()
# Out:
# 9.162151701506165

# %%
monthfebDF07["ArrDelay"].mean()
# Out:
# 13.51979483296776

# %%
monthmarDF07["ArrDelay"].mean()
# Out:
# 10.084908470559062

# %%
monthaprDF07["ArrDelay"].mean()
# Out:
# 8.516229825822615

# %%
monthmayDF07["ArrDelay"].mean()
# Out:
# 7.037888681043307

# %%
monthjunDF07["ArrDelay"].mean()
# Out:
# 16.17952800579826

# %%
monthjulDF07["ArrDelay"].mean()
# Out:
# 14.107679837700504

# %%
monthaugDF07["ArrDelay"].mean()
# Out:
# 12.57153344196042

# %%
monthsepDF07["ArrDelay"].mean()
# Out:
# 3.7494980749698845

# %%
monthoctDF07["ArrDelay"].mean()
# Out:
# 6.5082592714725775

# %%
monthnovDF07["ArrDelay"].mean()
# Out:
# 4.793344024722863

# %%
monthdecDF07["ArrDelay"].mean()
# Out:
# 16.213714049846818

# %%
#subsetting 2006 by days
import pandas as pd
df11 = pd.read_csv('2006.csv')
daymonDF = df11[df11['DayOfWeek']==1]
daytueDF = df11[df11['DayOfWeek']==2]
daywedDF = df11[df11['DayOfWeek']==3]
daythuDF = df11[df11['DayOfWeek']==4]
dayfriDF = df11[df11['DayOfWeek']==5]
daysatDF = df11[df11['DayOfWeek']==6]
daysunDF = df11[df11['DayOfWeek']==7]

# %%
#finding avg departure delay of each day in 2006

# %%
daymonDF["DepDelay"].mean()
# Out:
# 10.343309566994582

# %%
daytueDF["DepDelay"].mean()
# Out:
# 7.70399619869695

# %%
daywedDF["DepDelay"].mean()
# Out:
# 9.755770701319042

# %%
daythuDF["DepDelay"].mean()
# Out:
# 8.194027787617042

# %%
dayfriDF["DepDelay"].mean()
# Out:
# 8.540831601948103

# %%
daysatDF["DepDelay"].mean()
# Out:
# 12.933676964845205

# %%
daysunDF["DepDelay"].mean()
# Out:
# 12.703435985382688

# %%
#finding avg arrival delay of each day in 2006

# %%
daymonDF["ArrDelay"].mean()
# Out:
# 8.84253901796519

# %%
daytueDF["ArrDelay"].mean()
# Out:
# 6.19516278298006

# %%
daywedDF["ArrDelay"].mean()
# Out:
# 7.926261109192763

# %%
daythuDF["ArrDelay"].mean()
# Out:
# 6.42371018386133

# %%
dayfriDF["ArrDelay"].mean()
# Out:
# 6.887169414051858

# %%
daysatDF["ArrDelay"].mean()
# Out:
# 12.0455579467206

# %%
daysunDF["ArrDelay"].mean()
# Out:
# 11.311533589317666

# %%
#subsetting 2007 by days
import pandas as pd
df12 = pd.read_csv('2007.csv')
daymonDF07 = df12[df12['DayOfWeek']==1]
daytueDF07 = df12[df12['DayOfWeek']==2]
daywedDF07 = df12[df12['DayOfWeek']==3]
daythuDF07 = df12[df12['DayOfWeek']==4]
dayfriDF07 = df12[df12['DayOfWeek']==5]
daysatDF07 = df12[df12['DayOfWeek']==6]
daysunDF07 = df12[df12['DayOfWeek']==7]

# %%
#finding average departure delay of each day in 2007

# %%
daymonDF07["DepDelay"].mean()
# Out:
# 11.892415704828622

# %%
daytueDF07["DepDelay"].mean()
# Out:
# 9.398720587131987

# %%
daywedDF07["DepDelay"].mean()
# Out:
# 10.687132917683202

# %%
daythuDF07["DepDelay"].mean()
# Out:
# 12.886387368169817

# %%
dayfriDF07["DepDelay"].mean()
# Out:
# 13.576724963618544

# %%
daysatDF07["DepDelay"].mean()
# Out:
# 8.993704679140304

# %%
daysunDF07["DepDelay"].mean()
# Out:
# 11.978118657750775

# %%
#finding avg arrival delay of each day in 2007

# %%
daymonDF07["ArrDelay"].mean()
# Out:
# 10.513502556550229

# %%
daytueDF07["ArrDelay"].mean()
# Out:
# 8.263684434009868

# %%
daywedDF07["ArrDelay"].mean()
# Out:
# 9.962943847767281

# %%
daythuDF07["ArrDelay"].mean()
# Out:
# 12.685980155261941

# %%
dayfriDF07["ArrDelay"].mean()
# Out:
# 13.067675000697863

# %%
daysatDF07["ArrDelay"].mean()
# Out:
# 5.846600031017031

# %%
daysunDF07["ArrDelay"].mean()
# Out:
# 10.32957740663109
